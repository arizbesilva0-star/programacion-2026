# %%
"""
Integrantes del equipo:

Silva Silva Arizbe Itzari
González Hernández Isai
"""

'''
Created on May, 2026
@author: isaighernandez, arizbesilva0-star
'''
"""
Palabras repetidas
"""

def palabras_repetidas():

  nombre_archivo = input("Introduce el nombre del archivo: ")

  try:
    with open(nombre_archivo, "r") as archivo:
      palabra_anterior = ""

      for numero_linea, linea in enumerate(archivo, start=1):
        palabras = linea.split()

        for palabra in palabras:
          if palabra.lower() == palabra_anterior.lower():
            print(f"Palabra repetida en la línea {numero_linea}: {palabra}")
          palabra_anterior = palabra

  except FileNotFoundError:
    print(f"Error: El archivo {nombre_archivo} no existe")

# %%
palabras_repetidas()
# Out:
# Introduce el nombre del archivo: poema.txt
# Palabra repetida en la línea 3: noche
# Palabra repetida en la línea 6: viento
# Palabra repetida en la línea 12: tiempo
# Palabra repetida en la línea 18: alma

# %% [markdown]
# El poema del archivo era el siguiente:

# %%
El amor y la tristeza

La noche noche cae despacio
sobre mi corazón herido

Y el viento viento murmura
tu nombre entre los caminos

Te busco en silencio
entre sombras del olvido

Pero el tiempo tiempo pasa
y ya no vuelves conmigo

Mis ojos lloran
como lluvia en el vacío

Y mi alma alma triste
se pierde lejos contigo

Solo queda el eco
de aquel amor perdido.
