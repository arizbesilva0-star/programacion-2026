# %% [markdown]
# <a href="https://colab.research.google.com/github/arizbesilva0-star/programacion-2026/blob/main/Ayudantia_06_Mayo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  print(x)
except:
  print("Hay un error")
# Out:
# Hay un error

# %%
a=open("Archivo_texto.txt", "r")
print(a.read())
a.close()
# Out:
# Este archivo es una prueba

# %%
with open("Archivo_texto.txt")  as a:
 for i in a:
  print(i)
# Out:
# Este archivo es una prueba

# %%
with open("Archivo_texto.txt", "a") as a:
  a.write("/nEsta es una segunda linea")

# %%
with open("Archivo_texto.txt")  as a:
  print(a.read())
# Out:
# Este archivo es una prueba Esta es una segunda linea/nEsta es una segunda linea|nEsta es una segunda linea/nEsta es una segunda linea

# %%
with open("Archivo_texto.txt", "w") as a:
  a.write("Voy a sobreescribir todo el archivo de texto")

# %%
with open("Archivo_texto.txt")  as a:
 for i in a:
  print(i)
# Out:
# Voy a sobreescribir todo el archivo de texto

# %%
b = open("archivo2.txt", "x")

# %%
with open("archivo2.txt")  as a:
 for i in a:
  print(i)
